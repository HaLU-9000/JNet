# %%
import matplotlib.pyplot as plt
import numpy as np
from makedata   import make_data
from dataloader import Blur, CustomDataset

inp = make_data(200, (64, 64, 64))
out, out_ = CustomDataset(inp, 2, 32, 31, 30, 11).__getitem__(1)

print(out.shape)
print(out_.shape)
# Out:
# torch.Size([1, 16, 31, 30])
# torch.Size([1, 32, 31, 30])

# %%
plt.imshow(inp[0, 0], vmax=1, vmin=0)
plt.show()

# %%
img  = np.asarray(out[0])
img_ = np.asarray(out_[0])

# %%
img.shape
# Out:
# (16, 31, 30)

# %%
plt.imshow(img[3, :, :], vmax=1, vmin=0)
plt.show()

# %%
plt.imshow(img_[0, :, :])
plt.show()

# %%
import torch
def cut(inp, zsize, xsize, ysize):
        #inp = unfold(inp)
        inp = inp.unfold(3, zsize , zsize ,)\
                 .unfold(1, xsize , xsize ,)\
                 .unfold(2, ysize , ysize ,)
        #print(inp.shape)
        #num =  inp.shape[1] / zsize * inp.shape[2] /xsize  * inp.shape[3] / ysize
        num =  inp.shape[1] * inp.shape[2] * inp.shape[3]
        #print(num)
        return torch.reshape(inp, (int(num), 1, zsize, xsize, ysize))

# %%
hoge = torch.zeros(10, 10, 10)
hoge[:, 0:2, 0:1] = 1
hoge = hoge.unsqueeze(0)
plt.imshow(hoge[0, 0])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(hoge[0, 1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
a = cut(hoge, 5, 5, 5)

# %%
plt.imshow(a[0, 0, 0])

# %%
plt.imshow(a[0, 0, 0])

# %%
plt.imshow(a[0, 0, :, 0, :])

# %%
plt.imshow(a[0, 0, :, :, 0])

# %%
def cut2(inp, zsize, xsize, ysize):
        #inp = unfold(inp)
        inp = inp.unfold(3, zsize , zsize ,)\
                 .unfold(1, xsize , xsize ,)\
                 .unfold(2, ysize , ysize ,)
        
        #num =  inp.shape[1] / zsize * inp.shape[2] /xsize  * inp.shape[3] / ysize
        #num =  inp.shape[1] * inp.shape[2] * inp.shape[3]
        return inp
        #print(num)
        #return torch.reshape(inp, (int(num), 1, zsize, xsize, ysize))

# %%
a = cut2(hoge, 5, 5, 5)

# %%
plt.imshow(a[0, 0, 0, 0, 0])

# %%
def cut2(inp, zsize, xsize, ysize):
        #inp = unfold(inp)
        inp = inp.unfold(3, zsize , zsize ,)\
                 .unfold(1, xsize , xsize ,)\
                 .unfold(2, ysize , ysize ,)
        #num =  inp.shape[1] / zsize * inp.shape[2] /xsize  * inp.shape[3] / ysize
        #num =  inp.shape[1] * inp.shape[2] * inp.shape[3]
        return inp.flatten(1, 3).permute(1, 0, 2, 3, 4)
        #print(num)
        #return torch.reshape(inp, (int(num), 1, zsize, xsize, ysize))

# %%
a = cut2(hoge, 5, 5, 5)
