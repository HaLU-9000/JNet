# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
arr0 = np.load('roc_test/JNet_126_x1_softmax_temp_1e-6_0.npy')
arr1 = np.load('roc_test/JNet_83_x1_partial_0.npy')

# %%
arr0.shape
# Out:
# (3, 108629)

# %%
plt.figure(figsize=(4, 4))
plt.plot(arr0[0], arr0[1], lw=2, label = 'after training')
plt.plot(arr1[0], arr1[1], lw=2, label = 'before training')
plt.plot([0, 1], [0, 1], lw=2, linestyle='--')
plt.xlim([-0.02, 1.0])
plt.ylim([0.0, 1.02])
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')
