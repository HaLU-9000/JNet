# %% [markdown]
# # hinge function

# %%
import os
import sys
import numpy as np
from numpy.random import randint, choice, randn
import torch
import skimage.morphology
from skimage.morphology import ball, octahedron, cube
from matplotlib import cm
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.distributions as dist
import torch.nn.functional as F
from   scipy.stats import lognorm
import torch.special as S

# %%
def make_ball(r = 20, datasize = [128, 128, 128]):
    data     = np.zeros(datasize)
    datasize = np.array(datasize)
    s        = 'ball' # 'octahedron', 'cube'
    form     = getattr(skimage.morphology, s)(r).astype(np.float32)
    z, x, y  = datasize // 2 - r
    z_max    = min(z + form.shape[0], datasize[0])
    x_max    = min(x + form.shape[1], datasize[1])
    y_max    = min(y + form.shape[2], datasize[2])
    data[z : z + form.shape[0],
         x : x + form.shape[1],
         y : y + form.shape[2],]\
    += \
    form[0 : z_max - z        ,
         0 : x_max - x        ,
         0 : y_max - y        ,]
    data = data > 0
    data = torch.from_numpy(data).to(torch.float32)
    data = data.unsqueeze(0)
    return data

# %%
data = make_ball(r=20, datasize=[240, 128, 128])
nd_data = data.detach().numpy().copy()

# %%
plt.imshow(data[0, :, 64, 32:96], cmap='gray', vmax=1, vmin=0)

# %%
class Emission(nn.Module):
    def __init__(self, mu_z, sig_z, log_ez0):
        super().__init__()
        self.mu_z     = mu_z
        self.sig_z    = sig_z
        self.log_ez0  = log_ez0
        #self.mu_z_    = mu_z.item()
        #self.sig_z_   = sig_z.item()
        #self.logn_ppf = lognorm.ppf([0.99], 1,
        #                    loc=self.mu_z_, scale=self.sig_z_)[0]
        
    def sample(self, x):
        b = x.shape[0]
        pz0  = dist.LogNormal(loc   = self.mu_z.view( b, 1, 1, 1, 1).expand(*x.shape),
                              scale = self.sig_z.view(b, 1, 1, 1, 1).expand(*x.shape),)
        x    = x * pz0.sample().to(x.device)
        x    = torch.clip(x, min=0, max=1)
        #x    = x / self.logn_ppf
        return x

    def forward(self, x):
        x = x * torch.exp(self.log_ez0)
        return x


class Intensity(nn.Module):
    def __init__(self, gamma, image_size, initial_depth, voxel_size, scale,
                 device):
        super().__init__()
        init_d = initial_depth
        im_z,  \
        im_x,  \
        im_y   = image_size
        end_d  = im_z * voxel_size * scale
        depth  = init_d \
               + torch.linspace(0, end_d, im_z,).view(-1,1,1,).to(device)
        _intensity = torch.exp(-2 * depth * gamma) # gamma = 0.005
        self._intensity = _intensity.expand(image_size)

    def forward(self, x):
         x = x * self.intensity
         return x

    @property
    def intensity(self):
        return self._intensity


class Blur(nn.Module):
    def __init__(self, z, x, y, log_bet_z, log_bet_xy, log_k, log_l, scale, device,
                 psf_mode:str="double_exp", apply_hill=False):
        super().__init__()
        self.log_bet_z   = log_bet_z
        self.log_bet_xy  = log_bet_xy
        self.log_k   = log_k
        self.log_l   = log_l
        self.zscale, \
        self.xscale, \
        self.yscale  = scale
        self.z       = z
        self.x       = x
        self.y       = y
        self.device  = device
        self.zd      = self.distance(z)
        self.dp      = self.gen_distance_plane(xlen=x, ylen=y)
        self.mode    = psf_mode
        bet_xy       = torch.exp(self.log_bet_xy)
        bet_z        = torch.exp(self.log_bet_z )
        k        = torch.exp(self.log_k )
        self.psf     = self.gen_psf(bet_xy, bet_z, k).to(device)
        self.z_pad   = (z - self.zscale + 1) // 2
        self.x_pad   = (x - self.xscale + 1) // 2
        self.y_pad   = (y - self.yscale + 1) // 2
        self.stride  = (self.zscale, self.xscale, self.yscale)
        self.apply_hill = apply_hill

    def forward(self, x):
        x_shape = x.shape
        bet_xy  = torch.exp(self.log_bet_xy)
        bet_z   = torch.exp(self.log_bet_z )
        k   = torch.exp(self.log_k )
        psf = self.gen_psf(bet_xy, bet_z, k).to(self.device)
        _x   = F.conv3d(input   = x                                    ,
                        weight  = psf                                  ,
                        stride  = self.stride                          ,
                        padding = (self.z_pad, self.x_pad, self.y_pad,),)
        batch = _x.shape[0]
        x = torch.empty(size=(*x_shape[:2], *_x.shape[2:])).to(self.device)
        for b in range(batch):
                x[b, 0] = _x[b, b]
        if self.apply_hill:
            log_x = torch.log(x + 1e-8)
            log_l_x_k = torch.exp(self.log_k) * (self.log_l - log_x) #k = 0.5
            l_x_k = torch.exp(log_l_x_k)
            denom = torch.log(1. + l_x_k)
            x = torch.exp( - denom)
        return x

    def gen_psf(self, bet_xy, bet_z, k):
        if bet_xy.shape:
            b = bet_xy.shape[0]
        else:
            b = 1
        if self.mode == "student_t":
            psf_lateral = self.gen_2dstudent_t(self.dp, bet_xy, b)[:, None, None,    :,    :]
            psf_axial   = self.gen_1dstudent_t(self.zd, bet_z , b)[:, None,    :, None, None]
            psf = torch.exp(torch.log(psf_lateral) + torch.log(psf_axial))
        if self.mode == "gumbel":
            psf_lateral = self.gen_2dgumbel(self.dp, bet_xy, b)[:, None, None,    :,    :]
            psf_axial   = self.gen_1dgumbel(self.zd, bet_z , b)[:, None,    :, None, None]
            psf = torch.exp(torch.log(psf_lateral) + torch.log(psf_axial))
            if not k.shape:
                k = k.unsqueeze(0)
            psf = self.gen_double_exp_dist(psf, k[:, None, None, None, None],)
        if self.mode == "weibull":
            psf_lateral = self.gen_2dweibull(self.dp, bet_xy, b, k)[:, None, None,    :,    :]
            psf_axial   = self.gen_1dweibull(self.zd, bet_z , b, k)[:, None,    :, None, None]
            psf = torch.exp(torch.log(psf_lateral) + torch.log(psf_axial))
        if self.mode == "gaussian":
            psf_lateral = self.gen_2dnorm(self.dp, bet_xy, b)[:, None, None,    :,    :]
            psf_axial   = self.gen_1dnorm(self.zd, bet_z , b)[:, None,    :, None, None]
            psf = torch.exp(torch.log(psf_lateral) + torch.log(psf_axial)) # log-sum-exp technique
        if self.mode == "double_exp":
            psf_lateral = self.gen_2dnorm(self.dp, bet_xy, b)[:, None, None,    :,    :]
            psf_axial   = self.gen_1dnorm(self.zd, bet_z , b)[:, None,    :, None, None]
            psf = torch.exp(torch.log(psf_lateral) + torch.log(psf_axial))
            if not k.shape:
                k = k.unsqueeze(0)
            psf = self.gen_double_exp_dist(psf, k[:, None, None, None, None],)
        psf = psf / torch.sum(psf)
        return psf

    def _init_distance(self, length):
        return torch.zeros(length)

    def _distance_from_center(self, index, length):
        return abs(index - length // 2)

    def distance(self, length):
        distance = torch.zeros(length)
        for idx in range(length):
            distance[idx] = self._distance_from_center(idx, length)
        return distance.to(self.device)

    def gen_distance_plane(self, xlen, ylen):
        xd = self.distance(xlen)
        yd = self.distance(ylen)
        xp = xd.expand(ylen, xlen)
        yp = yd.expand(xlen, ylen).transpose(1, 0)
        dp = xp ** 2 + yp ** 2
        return dp.to(self.device)

    def gen_2dnorm(self, distance_plane, bet_xy, b):
        distance_plane = distance_plane.expand(b, *distance_plane.shape)
        bet_xy = bet_xy.view(b, 1, 1).expand(*distance_plane.shape)
        d_2      =  distance_plane / bet_xy ** 2
        normterm = (torch.pi * 2) * (bet_xy ** 2)
        norm     = torch.exp(-d_2 / 2) / normterm
        return norm

    def gen_1dnorm(self, distance, bet_z, b):
        distance = distance.expand(b, *distance.shape)
        bet_z = bet_z.view(b, 1).expand(*distance.shape)
        d_2      =  distance ** 2 / bet_z ** 2
        normterm = (torch.pi * 2) ** 0.5 * bet_z
        norm     = torch.exp(-d_2 / 2) / normterm
        return norm
    
    def gen_2dgumbel(self, distance_plane, bet_xy, b):
        distance_plane = distance_plane.expand(b, *distance_plane.shape)
        bet_xy = bet_xy.view(b, 1, 1).expand(*distance_plane.shape)
        d_2      =  distance_plane**0.5 / bet_xy
        norm     = torch.exp(-d_2)
        return norm

    def gen_1dgumbel(self, distance, bet_z, b):
        distance = distance.expand(b, *distance.shape)
        bet_z = bet_z.view(b, 1).expand(*distance.shape)
        d_2      =  distance / bet_z
        norm     = torch.exp(-d_2)
        return norm
    ##
    def gen_2dweibull(self, distance_plane, bet_xy, b, k):
        distance_plane = distance_plane.expand(b, *distance_plane.shape)
        bet_xy = bet_xy.view(b, 1, 1).expand(*distance_plane.shape)
        d_2      =  distance_plane**0.5 / bet_xy
        norm     = - d_2 ** k
        return norm
    ##
    def gen_1dweibull(self, distance, bet_z, b, k):
        distance = distance.expand(b, *distance.shape)
        bet_z = bet_z.view(b, 1).expand(*distance.shape)
        d_2      =  distance / bet_z
        norm     = - d_2 ** k
        return norm

    def gen_2dstudent_t(self, distance_plane, bet_xy, b):
        distance_plane = distance_plane.expand(b, *distance_plane.shape)
        bet_xy = bet_xy.view(b, 1, 1).expand(*distance_plane.shape)
        d_2      =  (distance_plane / bet_xy + 1) ** -((bet_xy + 1) / 2)
        normterm = torch.exp(S.gammaln((bet_xy + 1) / 2) - S.gammaln(bet_xy / 2)) / (torch.pi * bet_xy) ** 0.5
        norm     = normterm * d_2 
        return norm

    def gen_1dstudent_t(self, distance, bet_z, b):
        distance = distance.expand(b, *distance.shape)
        bet_z = bet_z.view(b, 1).expand(*distance.shape)
        d_2      =  (distance ** 2 / bet_z + 1) ** -((bet_z + 1) / 2)
        normterm = torch.exp(S.gammaln((bet_z + 1) / 2) - S.gammaln(bet_z / 2)) / (torch.pi * bet_z) ** 0.5
        norm     = normterm * d_2 
        return norm

    def gen_double_exp_dist(self, norm, k,):
        pdf  = 1. - torch.exp(-k * norm)
        return pdf


class Noise(nn.Module):
    def __init__(self, sig_eps):
        super().__init__()
        self.sig_eps = sig_eps

    def forward(self, x):
        return x
    
    def sample(self, x):
        b = x.shape[0]
        px = dist.Normal(loc   = x           ,
                         scale = self.sig_eps.view(b, 1, 1, 1, 1).expand(*x.shape).to(x.device))
        x  = px.rsample()
        x  = torch.clip(x, min=0, max=1)
        return x


class PreProcess(nn.Module):
    def __init__(self, min, max):
        super().__init__()
        self.min = min
        self.max = max

    def forward(self, x):
        x = torch.clip(x, min=self.min, max=self.max)
        x = (x - self.min) / (self.max - self.min)
        return x


class ImagingProcess(nn.Module):
    def __init__(self, device, params,
                 z, x, y, postmin=0., postmax=1.,
                 mode:str="train",dist="double_exp", apply_hill=False):
        super().__init__()
        self.device = device
        self.z = z
        self.x = x
        self.y = y
        self.postmin = postmin
        self.postmax = postmax
        if mode == "train":
            self.mu_z   = torch.tensor(params["mu_z"])
            self.sig_z  = torch.tensor(params["sig_z"])
            self.log_ez0 = nn.Parameter((torch.tensor(params["mu_z"] + 0.5 * params["sig_z"] ** 2)).to(device), requires_grad=True)
            self.log_bet_z  = nn.Parameter(torch.tensor(params["log_bet_z" ]).to(device), requires_grad=True)
            self.log_bet_xy = nn.Parameter(torch.tensor(params["log_bet_xy"]).to(device), requires_grad=True)
            self.log_k  = nn.Parameter(torch.tensor(params["log_k" ]).to(device), requires_grad=True)
            self.log_l  = nn.Parameter(torch.tensor(params["log_l" ]).to(device), requires_grad=True)
        elif mode == "dataset":
            self.mu_z    = nn.Parameter(torch.tensor(params["mu_z"  ]), requires_grad=False)
            self.sig_z   = nn.Parameter(torch.tensor(params["sig_z" ]), requires_grad=False)
            self.log_bet_z   = nn.Parameter(torch.tensor(params["log_bet_z" ]), requires_grad=False)
            self.log_bet_xy  = nn.Parameter(torch.tensor(params["log_bet_xy"]), requires_grad=False)
        else:
            raise(NotImplementedError())
        scale = [params["scale"], 1, 1]
        self.emission   = Emission(mu_z    = self.mu_z ,
                                   sig_z   = self.sig_z,
                                   log_ez0 = self.log_ez0,)
        self.blur       = Blur(z           = z              ,
                               x           = x              ,
                               y           = y              ,
                               log_bet_z   = self.log_bet_z ,
                               log_bet_xy  = self.log_bet_xy,
                               log_k       = self.log_k     ,
                               log_l       = self.log_l     ,
                               scale       = scale          ,
                               device      = device         ,
                               psf_mode    = dist           ,
                               apply_hill  = apply_hill     ,)
        self.noise      = Noise(torch.tensor(params["sig_eps"]))
        self.preprocess = PreProcess(min=postmin, max=postmax)

    def forward(self, x):
        x = self.emission(x)
        x = self.blur(x)
        x = x + (torch.clamp(x, min=0., max=1.) - x).detach()
        x = self.preprocess(x)
        return x

    def sample(self, x):
        x = self.emission.sample(x)
        x = self.blur(x)
        x = self.noise.sample(x)
        x = self.preprocess(x)
        x = torch.clamp(x, min=0., max=1.)
        return x
    
    def sample_from_params(self, x, params):
        if isinstance(params["scale"], torch.Tensor):
            z = int(params["scale"][0])
        else:
            z = params["scale"]
        scale = [z, 1, 1] ## use only one scale
        emission   = Emission(tt(params["mu_z"]), tt(params["sig_z"]))
        blur       = Blur(self.z, self.x, self.y,
                          tt(params["log_bet_z"]), tt(params["log_bet_xy"]),
                          tt(params["log_k"]), scale, self.device)
        noise      = Noise(tt(params["sig_eps"]))
        preprocess = PreProcess(min=self.postmin, max=self.postmax)
        x = emission.sample(x)
        x = blur(x)
        x = noise.sample(x)
        x = preprocess(x)
        return x

# %%
dirpath = "_beads_roi_extracted"
beadslist = [os.path.join(dirpath, f) for f in sorted(os.listdir(dirpath))]
beadslist
label = torch.load(beadslist[0], map_location="cuda").to(torch.float32)

# %%
loss_fn = nn.MSELoss()

def normalize(array):
    return array / torch.sum(array)

def train_loop(obj, model, label, optimizer, epoch):
    for _ in range(epoch):
        if obj.dim() == 4:
            obj = obj.unsqueeze(0)
        x = model(obj)
        if x.dim() == 5:
            x = x.squeeze(0)
        loss = loss_fn(x, label)
        optimizer.zero_grad()
        loss.backward(retain_graph=True)
        optimizer.step()
        if _ % 10 == 0:
            print(f'epoch {_}, loss {loss:.8f}', model.state_dict())
    return loss.item()

# %% [markdown]
# # gaussian
# ## no clip, with hinge

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
obj = data.to(device)
scale_factor = [10, 1, 1]
z = 161
x = 3
y = 3
params = {"mu_z"       : 0.2    ,
          "sig_z"      : 0.2    ,
          "log_bet_z"  : np.log(20.).item(),
          "log_bet_xy" : np.log(1.).item(),
          "log_k"  : np.log(1.).item(),
          "log_l"  : np.log(1.).item(),
          "sig_eps"    : 0.01   ,
          "scale"      : 10
          }
beadslist = [os.path.join(dirpath, f) for f in sorted(os.listdir(dirpath))]
torch.autograd.set_detect_anomaly(True)
losses = []
beadslist.pop(1)
beadslist.pop(1)
beadslist.pop(-1)
fig, ax = plt.subplots(nrows = 6, ncols=len(beadslist), figsize=(20, 20))
for i, bead in enumerate(beadslist):
    dirpath = "_beads_roi_extracted"
    label = torch.load(bead, map_location="cuda").to(torch.float32)
    blur = ImagingProcess(device       = device           ,
                          params       = params           ,
                          z            = z                ,
                          x            = x                ,
                          y            = y                ,
                          mode         = "train"          ,
                          dist         = "gaussian"       ,
                          apply_hill   = False            ,
                          )
    optimizer = torch.optim.Adam(blur.parameters(), lr=1e-2)
    print(bead[21:-3])
    loss = train_loop(obj, blur, label, optimizer, 100)
    label = label.detach().to("cpu")
    x_label = label[0, :, 64, 32:96]
    y_label = label[0, :, 32:96, 64]
    t = data.to(device).unsqueeze(0)
    t = blur(t).squeeze(0)
    t = t.detach().to('cpu')
    x_img = t[0, :, 64, 32:96]
    y_img = t[0, :, 32:96, 64]
    ax[0, i].imshow(x_label, aspect=10, vmin=0, vmax=1,cmap='gray')
    ax[1, i].imshow(x_img, aspect=10, vmin=0, vmax=1,cmap='gray')
    ax[2, i].imshow((x_img - x_label + 1) / 2, aspect=10, cmap='seismic')
    ax[3, i].imshow(y_label, aspect=10, vmin=0, vmax=1,cmap='gray')
    ax[4, i].imshow(y_img, aspect=10, vmin=0, vmax=1,cmap='gray')
    ax[5, i].imshow((y_img - y_label + 1) / 2, aspect=10, cmap='seismic')
    losses.append(loss)
plt.show()
losses
# Out:
# beads_001_roi000
# epoch 0, loss 0.00244451 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00225152 OrderedDict([('log_ez0', tensor(0.3288, device='cuda:0')), ('log_bet_z', tensor(3.1047, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3288, device='cuda:0')), ('blur.log_bet_z', tensor(3.1047, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00212281 OrderedDict([('log_ez0', tensor(0.4202, device='cuda:0')), ('log_bet_z', tensor(3.1975, device='cuda:0')), ('log_bet_xy', tensor(0.2077, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4202, device='cuda:0')), ('blur.log_bet_z', tensor(3.1975, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2077, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00206356 OrderedDict([('log_ez0', tensor(0.4939, device='cuda:0')), ('log_bet_z', tensor(3.2749, device='cuda:0')), ('log_bet_xy', tensor(0.3030, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4939, device='cuda:0')), ('blur.log_bet_z', tensor(3.2749, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3030, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00205196 OrderedDict([('log_ez0', tensor(0.5392, device='cuda:0')), ('log_bet_z', tensor(3.3251, device='cuda:0')), ('log_bet_xy', tensor(0.3940, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5392, device='cuda:0')), ('blur.log_bet_z', tensor(3.3251, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3940, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00205322 OrderedDict([('log_ez0', tensor(0.5541, device='cuda:0')), ('log_bet_z', tensor(3.3422, device='cuda:0')), ('log_bet_xy', tensor(0.4789, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5541, device='cuda:0')), ('blur.log_bet_z', tensor(3.3422, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4789, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00205206 OrderedDict([('log_ez0', tensor(0.5490, device='cuda:0')), ('log_bet_z', tensor(3.3361, device='cuda:0')), ('log_bet_xy', tensor(0.5562, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5490, device='cuda:0')), ('blur.log_bet_z', tensor(3.3361, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5562, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00205062 OrderedDict([('log_ez0', tensor(0.5386, device='cuda:0')), ('log_bet_z', tensor(3.3244, device='cuda:0')), ('log_bet_xy', tensor(0.6255, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5386, device='cuda:0')), ('blur.log_bet_z', tensor(3.3244, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6255, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00205026 OrderedDict([('log_ez0', tensor(0.5324, device='cuda:0')), ('log_bet_z', tensor(3.3177, device='cuda:0')), ('log_bet_xy', tensor(0.6876, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5324, device='cuda:0')), ('blur.log_bet_z', tensor(3.3177, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6876, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00205007 OrderedDict([('log_ez0', tensor(0.5318, device='cuda:0')), ('log_bet_z', tensor(3.3169, device='cuda:0')), ('log_bet_xy', tensor(0.7437, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5318, device='cuda:0')), ('blur.log_bet_z', tensor(3.3169, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7437, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi003
# epoch 0, loss 0.00808110 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00792065 OrderedDict([('log_ez0', tensor(0.3279, device='cuda:0')), ('log_bet_z', tensor(3.1053, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3279, device='cuda:0')), ('blur.log_bet_z', tensor(3.1053, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00782245 OrderedDict([('log_ez0', tensor(0.4129, device='cuda:0')), ('log_bet_z', tensor(3.2013, device='cuda:0')), ('log_bet_xy', tensor(0.2075, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4129, device='cuda:0')), ('blur.log_bet_z', tensor(3.2013, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2075, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00778313 OrderedDict([('log_ez0', tensor(0.4706, device='cuda:0')), ('log_bet_z', tensor(3.2844, device='cuda:0')), ('log_bet_xy', tensor(0.3018, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4706, device='cuda:0')), ('blur.log_bet_z', tensor(3.2844, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3018, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00777755 OrderedDict([('log_ez0', tensor(0.4982, device='cuda:0')), ('log_bet_z', tensor(3.3368, device='cuda:0')), ('log_bet_xy', tensor(0.3899, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4982, device='cuda:0')), ('blur.log_bet_z', tensor(3.3368, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3899, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00777846 OrderedDict([('log_ez0', tensor(0.5057, device='cuda:0')), ('log_bet_z', tensor(3.3494, device='cuda:0')), ('log_bet_xy', tensor(0.4701, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5057, device='cuda:0')), ('blur.log_bet_z', tensor(3.3494, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4701, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00777716 OrderedDict([('log_ez0', tensor(0.5014, device='cuda:0')), ('log_bet_z', tensor(3.3387, device='cuda:0')), ('log_bet_xy', tensor(0.5424, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5014, device='cuda:0')), ('blur.log_bet_z', tensor(3.3387, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5424, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00777614 OrderedDict([('log_ez0', tensor(0.4929, device='cuda:0')), ('log_bet_z', tensor(3.3262, device='cuda:0')), ('log_bet_xy', tensor(0.6078, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4929, device='cuda:0')), ('blur.log_bet_z', tensor(3.3262, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6078, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00777589 OrderedDict([('log_ez0', tensor(0.4885, device='cuda:0')), ('log_bet_z', tensor(3.3201, device='cuda:0')), ('log_bet_xy', tensor(0.6669, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4885, device='cuda:0')), ('blur.log_bet_z', tensor(3.3201, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6669, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00777570 OrderedDict([('log_ez0', tensor(0.4890, device='cuda:0')), ('log_bet_z', tensor(3.3201, device='cuda:0')), ('log_bet_xy', tensor(0.7210, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4890, device='cuda:0')), ('blur.log_bet_z', tensor(3.3201, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7210, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi004
# epoch 0, loss 0.00694176 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00662827 OrderedDict([('log_ez0', tensor(0.3294, device='cuda:0')), ('log_bet_z', tensor(3.0774, device='cuda:0')), ('log_bet_xy', tensor(0.1098, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3294, device='cuda:0')), ('blur.log_bet_z', tensor(3.0774, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1098, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00637175 OrderedDict([('log_ez0', tensor(0.4255, device='cuda:0')), ('log_bet_z', tensor(3.1491, device='cuda:0')), ('log_bet_xy', tensor(0.2092, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4255, device='cuda:0')), ('blur.log_bet_z', tensor(3.1491, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2092, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00618884 OrderedDict([('log_ez0', tensor(0.5135, device='cuda:0')), ('log_bet_z', tensor(3.2166, device='cuda:0')), ('log_bet_xy', tensor(0.3075, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5135, device='cuda:0')), ('blur.log_bet_z', tensor(3.2166, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3075, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00608401 OrderedDict([('log_ez0', tensor(0.5878, device='cuda:0')), ('log_bet_z', tensor(3.2745, device='cuda:0')), ('log_bet_xy', tensor(0.4038, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5878, device='cuda:0')), ('blur.log_bet_z', tensor(3.2745, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4038, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00604228 OrderedDict([('log_ez0', tensor(0.6422, device='cuda:0')), ('log_bet_z', tensor(3.3177, device='cuda:0')), ('log_bet_xy', tensor(0.4967, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6422, device='cuda:0')), ('blur.log_bet_z', tensor(3.3177, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4967, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00603419 OrderedDict([('log_ez0', tensor(0.6738, device='cuda:0')), ('log_bet_z', tensor(3.3429, device='cuda:0')), ('log_bet_xy', tensor(0.5846, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6738, device='cuda:0')), ('blur.log_bet_z', tensor(3.3429, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5846, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00603455 OrderedDict([('log_ez0', tensor(0.6853, device='cuda:0')), ('log_bet_z', tensor(3.3521, device='cuda:0')), ('log_bet_xy', tensor(0.6660, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6853, device='cuda:0')), ('blur.log_bet_z', tensor(3.3521, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6660, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00603414 OrderedDict([('log_ez0', tensor(0.6843, device='cuda:0')), ('log_bet_z', tensor(3.3513, device='cuda:0')), ('log_bet_xy', tensor(0.7398, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6843, device='cuda:0')), ('blur.log_bet_z', tensor(3.3513, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7398, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00603326 OrderedDict([('log_ez0', tensor(0.6788, device='cuda:0')), ('log_bet_z', tensor(3.3468, device='cuda:0')), ('log_bet_xy', tensor(0.8061, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6788, device='cuda:0')), ('blur.log_bet_z', tensor(3.3468, device='cuda:0')), ('blur.log_bet_xy', tensor(0.8061, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi005
# epoch 0, loss 0.00215096 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00196141 OrderedDict([('log_ez0', tensor(0.3288, device='cuda:0')), ('log_bet_z', tensor(3.1042, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3288, device='cuda:0')), ('blur.log_bet_z', tensor(3.1042, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00183884 OrderedDict([('log_ez0', tensor(0.4201, device='cuda:0')), ('log_bet_z', tensor(3.1939, device='cuda:0')), ('log_bet_xy', tensor(0.2078, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4201, device='cuda:0')), ('blur.log_bet_z', tensor(3.1939, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2078, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00178668 OrderedDict([('log_ez0', tensor(0.4930, device='cuda:0')), ('log_bet_z', tensor(3.2641, device='cuda:0')), ('log_bet_xy', tensor(0.3035, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4930, device='cuda:0')), ('blur.log_bet_z', tensor(3.2641, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3035, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00177913 OrderedDict([('log_ez0', tensor(0.5352, device='cuda:0')), ('log_bet_z', tensor(3.3065, device='cuda:0')), ('log_bet_xy', tensor(0.3951, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5352, device='cuda:0')), ('blur.log_bet_z', tensor(3.3065, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3951, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00178044 OrderedDict([('log_ez0', tensor(0.5458, device='cuda:0')), ('log_bet_z', tensor(3.3183, device='cuda:0')), ('log_bet_xy', tensor(0.4805, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5458, device='cuda:0')), ('blur.log_bet_z', tensor(3.3183, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4805, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00177877 OrderedDict([('log_ez0', tensor(0.5379, device='cuda:0')), ('log_bet_z', tensor(3.3097, device='cuda:0')), ('log_bet_xy', tensor(0.5581, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5379, device='cuda:0')), ('blur.log_bet_z', tensor(3.3097, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5581, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00177750 OrderedDict([('log_ez0', tensor(0.5271, device='cuda:0')), ('log_bet_z', tensor(3.2985, device='cuda:0')), ('log_bet_xy', tensor(0.6274, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5271, device='cuda:0')), ('blur.log_bet_z', tensor(3.2985, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6274, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00177726 OrderedDict([('log_ez0', tensor(0.5220, device='cuda:0')), ('log_bet_z', tensor(3.2934, device='cuda:0')), ('log_bet_xy', tensor(0.6892, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5220, device='cuda:0')), ('blur.log_bet_z', tensor(3.2934, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6892, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00177704 OrderedDict([('log_ez0', tensor(0.5226, device='cuda:0')), ('log_bet_z', tensor(3.2938, device='cuda:0')), ('log_bet_xy', tensor(0.7452, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5226, device='cuda:0')), ('blur.log_bet_z', tensor(3.2938, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7452, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi006
# epoch 0, loss 0.00291181 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00262610 OrderedDict([('log_ez0', tensor(0.3295, device='cuda:0')), ('log_bet_z', tensor(3.0997, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3295, device='cuda:0')), ('blur.log_bet_z', tensor(3.0997, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00240246 OrderedDict([('log_ez0', tensor(0.4253, device='cuda:0')), ('log_bet_z', tensor(3.1689, device='cuda:0')), ('log_bet_xy', tensor(0.2084, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4253, device='cuda:0')), ('blur.log_bet_z', tensor(3.1689, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2084, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00225461 OrderedDict([('log_ez0', tensor(0.5113, device='cuda:0')), ('log_bet_z', tensor(3.2343, device='cuda:0')), ('log_bet_xy', tensor(0.3061, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5113, device='cuda:0')), ('blur.log_bet_z', tensor(3.2343, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3061, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00218147 OrderedDict([('log_ez0', tensor(0.5804, device='cuda:0')), ('log_bet_z', tensor(3.2898, device='cuda:0')), ('log_bet_xy', tensor(0.4016, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5804, device='cuda:0')), ('blur.log_bet_z', tensor(3.2898, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4016, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00216036 OrderedDict([('log_ez0', tensor(0.6263, device='cuda:0')), ('log_bet_z', tensor(3.3264, device='cuda:0')), ('log_bet_xy', tensor(0.4932, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6263, device='cuda:0')), ('blur.log_bet_z', tensor(3.3264, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4932, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00215930 OrderedDict([('log_ez0', tensor(0.6477, device='cuda:0')), ('log_bet_z', tensor(3.3436, device='cuda:0')), ('log_bet_xy', tensor(0.5792, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6477, device='cuda:0')), ('blur.log_bet_z', tensor(3.3436, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5792, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00215949 OrderedDict([('log_ez0', tensor(0.6507, device='cuda:0')), ('log_bet_z', tensor(3.3463, device='cuda:0')), ('log_bet_xy', tensor(0.6580, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6507, device='cuda:0')), ('blur.log_bet_z', tensor(3.3463, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6580, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00215840 OrderedDict([('log_ez0', tensor(0.6450, device='cuda:0')), ('log_bet_z', tensor(3.3413, device='cuda:0')), ('log_bet_xy', tensor(0.7289, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6450, device='cuda:0')), ('blur.log_bet_z', tensor(3.3413, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7289, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00215767 OrderedDict([('log_ez0', tensor(0.6386, device='cuda:0')), ('log_bet_z', tensor(3.3362, device='cuda:0')), ('log_bet_xy', tensor(0.7923, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6386, device='cuda:0')), ('blur.log_bet_z', tensor(3.3362, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7923, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi007
# epoch 0, loss 0.00500111 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00464593 OrderedDict([('log_ez0', tensor(0.3295, device='cuda:0')), ('log_bet_z', tensor(3.1059, device='cuda:0')), ('log_bet_xy', tensor(0.1095, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3295, device='cuda:0')), ('blur.log_bet_z', tensor(3.1059, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1095, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00432069 OrderedDict([('log_ez0', tensor(0.4260, device='cuda:0')), ('log_bet_z', tensor(3.2065, device='cuda:0')), ('log_bet_xy', tensor(0.2075, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4260, device='cuda:0')), ('blur.log_bet_z', tensor(3.2065, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2075, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00404139 OrderedDict([('log_ez0', tensor(0.5162, device='cuda:0')), ('log_bet_z', tensor(3.3066, device='cuda:0')), ('log_bet_xy', tensor(0.3028, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5162, device='cuda:0')), ('blur.log_bet_z', tensor(3.3066, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3028, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00382277 OrderedDict([('log_ez0', tensor(0.5960, device='cuda:0')), ('log_bet_z', tensor(3.4037, device='cuda:0')), ('log_bet_xy', tensor(0.3943, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5960, device='cuda:0')), ('blur.log_bet_z', tensor(3.4037, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3943, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00367252 OrderedDict([('log_ez0', tensor(0.6615, device='cuda:0')), ('log_bet_z', tensor(3.4935, device='cuda:0')), ('log_bet_xy', tensor(0.4815, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6615, device='cuda:0')), ('blur.log_bet_z', tensor(3.4935, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4815, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00358548 OrderedDict([('log_ez0', tensor(0.7104, device='cuda:0')), ('log_bet_z', tensor(3.5708, device='cuda:0')), ('log_bet_xy', tensor(0.5635, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7104, device='cuda:0')), ('blur.log_bet_z', tensor(3.5708, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5635, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00354436 OrderedDict([('log_ez0', tensor(0.7424, device='cuda:0')), ('log_bet_z', tensor(3.6318, device='cuda:0')), ('log_bet_xy', tensor(0.6399, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7424, device='cuda:0')), ('blur.log_bet_z', tensor(3.6318, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6399, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00352895 OrderedDict([('log_ez0', tensor(0.7608, device='cuda:0')), ('log_bet_z', tensor(3.6747, device='cuda:0')), ('log_bet_xy', tensor(0.7104, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7608, device='cuda:0')), ('blur.log_bet_z', tensor(3.6747, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7104, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00352458 OrderedDict([('log_ez0', tensor(0.7702, device='cuda:0')), ('log_bet_z', tensor(3.7010, device='cuda:0')), ('log_bet_xy', tensor(0.7749, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7702, device='cuda:0')), ('blur.log_bet_z', tensor(3.7010, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7749, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi008
# epoch 0, loss 0.00158797 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00145926 OrderedDict([('log_ez0', tensor(0.3268, device='cuda:0')), ('log_bet_z', tensor(3.1054, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3268, device='cuda:0')), ('blur.log_bet_z', tensor(3.1054, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00138913 OrderedDict([('log_ez0', tensor(0.4038, device='cuda:0')), ('log_bet_z', tensor(3.2016, device='cuda:0')), ('log_bet_xy', tensor(0.2073, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4038, device='cuda:0')), ('blur.log_bet_z', tensor(3.2016, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2073, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00136543 OrderedDict([('log_ez0', tensor(0.4459, device='cuda:0')), ('log_bet_z', tensor(3.2816, device='cuda:0')), ('log_bet_xy', tensor(0.3005, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4459, device='cuda:0')), ('blur.log_bet_z', tensor(3.2816, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3005, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00136423 OrderedDict([('log_ez0', tensor(0.4642, device='cuda:0')), ('log_bet_z', tensor(3.3228, device='cuda:0')), ('log_bet_xy', tensor(0.3862, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4642, device='cuda:0')), ('blur.log_bet_z', tensor(3.3228, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3862, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00136430 OrderedDict([('log_ez0', tensor(0.4691, device='cuda:0')), ('log_bet_z', tensor(3.3246, device='cuda:0')), ('log_bet_xy', tensor(0.4636, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4691, device='cuda:0')), ('blur.log_bet_z', tensor(3.3246, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4636, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00136292 OrderedDict([('log_ez0', tensor(0.4618, device='cuda:0')), ('log_bet_z', tensor(3.3115, device='cuda:0')), ('log_bet_xy', tensor(0.5336, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4618, device='cuda:0')), ('blur.log_bet_z', tensor(3.3115, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5336, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00136229 OrderedDict([('log_ez0', tensor(0.4540, device='cuda:0')), ('log_bet_z', tensor(3.3003, device='cuda:0')), ('log_bet_xy', tensor(0.5969, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4540, device='cuda:0')), ('blur.log_bet_z', tensor(3.3003, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5969, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00136211 OrderedDict([('log_ez0', tensor(0.4526, device='cuda:0')), ('log_bet_z', tensor(3.2961, device='cuda:0')), ('log_bet_xy', tensor(0.6545, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4526, device='cuda:0')), ('blur.log_bet_z', tensor(3.2961, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6545, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00136189 OrderedDict([('log_ez0', tensor(0.4536, device='cuda:0')), ('log_bet_z', tensor(3.2982, device='cuda:0')), ('log_bet_xy', tensor(0.7075, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4536, device='cuda:0')), ('blur.log_bet_z', tensor(3.2982, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7075, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi009
# epoch 0, loss 0.00120665 OrderedDict([('log_ez0', tensor(0.2100, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2100, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00107971 OrderedDict([('log_ez0', tensor(0.1602, device='cuda:0')), ('log_bet_z', tensor(3.1022, device='cuda:0')), ('log_bet_xy', tensor(0.1069, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.1602, device='cuda:0')), ('blur.log_bet_z', tensor(3.1022, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1069, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00098957 OrderedDict([('log_ez0', tensor(0.2238, device='cuda:0')), ('log_bet_z', tensor(3.1889, device='cuda:0')), ('log_bet_xy', tensor(0.1960, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2238, device='cuda:0')), ('blur.log_bet_z', tensor(3.1889, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1960, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00092029 OrderedDict([('log_ez0', tensor(0.2944, device='cuda:0')), ('log_bet_z', tensor(3.2705, device='cuda:0')), ('log_bet_xy', tensor(0.2807, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2944, device='cuda:0')), ('blur.log_bet_z', tensor(3.2705, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2807, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00087757 OrderedDict([('log_ez0', tensor(0.3290, device='cuda:0')), ('log_bet_z', tensor(3.3461, device='cuda:0')), ('log_bet_xy', tensor(0.3615, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3290, device='cuda:0')), ('blur.log_bet_z', tensor(3.3461, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3615, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00085658 OrderedDict([('log_ez0', tensor(0.3513, device='cuda:0')), ('log_bet_z', tensor(3.4059, device='cuda:0')), ('log_bet_xy', tensor(0.4361, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3513, device='cuda:0')), ('blur.log_bet_z', tensor(3.4059, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4361, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00084894 OrderedDict([('log_ez0', tensor(0.3746, device='cuda:0')), ('log_bet_z', tensor(3.4458, device='cuda:0')), ('log_bet_xy', tensor(0.5040, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3746, device='cuda:0')), ('blur.log_bet_z', tensor(3.4458, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5040, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00084718 OrderedDict([('log_ez0', tensor(0.3844, device='cuda:0')), ('log_bet_z', tensor(3.4691, device='cuda:0')), ('log_bet_xy', tensor(0.5664, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3844, device='cuda:0')), ('blur.log_bet_z', tensor(3.4691, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5664, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00084697 OrderedDict([('log_ez0', tensor(0.3872, device='cuda:0')), ('log_bet_z', tensor(3.4795, device='cuda:0')), ('log_bet_xy', tensor(0.6239, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3872, device='cuda:0')), ('blur.log_bet_z', tensor(3.4795, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6239, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00084687 OrderedDict([('log_ez0', tensor(0.3893, device='cuda:0')), ('log_bet_z', tensor(3.4813, device='cuda:0')), ('log_bet_xy', tensor(0.6771, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3893, device='cuda:0')), ('blur.log_bet_z', tensor(3.4813, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6771, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_001_roi010
# epoch 0, loss 0.00381570 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(2.9857, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(2.9857, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00346265 OrderedDict([('log_ez0', tensor(0.3290, device='cuda:0')), ('log_bet_z', tensor(3.0155, device='cuda:0')), ('log_bet_xy', tensor(0.1103, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3290, device='cuda:0')), ('blur.log_bet_z', tensor(3.0155, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1103, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00316254 OrderedDict([('log_ez0', tensor(0.4250, device='cuda:0')), ('log_bet_z', tensor(3.1056, device='cuda:0')), ('log_bet_xy', tensor(0.2102, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4250, device='cuda:0')), ('blur.log_bet_z', tensor(3.1056, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2102, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00293731 OrderedDict([('log_ez0', tensor(0.5150, device='cuda:0')), ('log_bet_z', tensor(3.1731, device='cuda:0')), ('log_bet_xy', tensor(0.3083, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5150, device='cuda:0')), ('blur.log_bet_z', tensor(3.1731, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3083, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00279558 OrderedDict([('log_ez0', tensor(0.5930, device='cuda:0')), ('log_bet_z', tensor(3.2343, device='cuda:0')), ('log_bet_xy', tensor(0.4045, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5930, device='cuda:0')), ('blur.log_bet_z', tensor(3.2343, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4045, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00272754 OrderedDict([('log_ez0', tensor(0.6537, device='cuda:0')), ('log_bet_z', tensor(3.2852, device='cuda:0')), ('log_bet_xy', tensor(0.4976, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6537, device='cuda:0')), ('blur.log_bet_z', tensor(3.2852, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4976, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00270622 OrderedDict([('log_ez0', tensor(0.6938, device='cuda:0')), ('log_bet_z', tensor(3.3150, device='cuda:0')), ('log_bet_xy', tensor(0.5861, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6938, device='cuda:0')), ('blur.log_bet_z', tensor(3.3150, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5861, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00270368 OrderedDict([('log_ez0', tensor(0.7136, device='cuda:0')), ('log_bet_z', tensor(3.3318, device='cuda:0')), ('log_bet_xy', tensor(0.6688, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7136, device='cuda:0')), ('blur.log_bet_z', tensor(3.3318, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6688, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00270374 OrderedDict([('log_ez0', tensor(0.7185, device='cuda:0')), ('log_bet_z', tensor(3.3350, device='cuda:0')), ('log_bet_xy', tensor(0.7446, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7185, device='cuda:0')), ('blur.log_bet_z', tensor(3.3350, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7446, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00270317 OrderedDict([('log_ez0', tensor(0.7157, device='cuda:0')), ('log_bet_z', tensor(3.3330, device='cuda:0')), ('log_bet_xy', tensor(0.8130, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7157, device='cuda:0')), ('blur.log_bet_z', tensor(3.3330, device='cuda:0')), ('blur.log_bet_xy', tensor(0.8130, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_002_roi000
# epoch 0, loss 0.00329460 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00290030 OrderedDict([('log_ez0', tensor(0.3297, device='cuda:0')), ('log_bet_z', tensor(3.1022, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3297, device='cuda:0')), ('blur.log_bet_z', tensor(3.1022, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00255768 OrderedDict([('log_ez0', tensor(0.4278, device='cuda:0')), ('log_bet_z', tensor(3.1804, device='cuda:0')), ('log_bet_xy', tensor(0.2083, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4278, device='cuda:0')), ('blur.log_bet_z', tensor(3.1804, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2083, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00228391 OrderedDict([('log_ez0', tensor(0.5207, device='cuda:0')), ('log_bet_z', tensor(3.2442, device='cuda:0')), ('log_bet_xy', tensor(0.3061, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5207, device='cuda:0')), ('blur.log_bet_z', tensor(3.2442, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3061, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00209223 OrderedDict([('log_ez0', tensor(0.6039, device='cuda:0')), ('log_bet_z', tensor(3.3100, device='cuda:0')), ('log_bet_xy', tensor(0.4028, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6039, device='cuda:0')), ('blur.log_bet_z', tensor(3.3100, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4028, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00198254 OrderedDict([('log_ez0', tensor(0.6729, device='cuda:0')), ('log_bet_z', tensor(3.3644, device='cuda:0')), ('log_bet_xy', tensor(0.4971, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6729, device='cuda:0')), ('blur.log_bet_z', tensor(3.3644, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4971, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00193687 OrderedDict([('log_ez0', tensor(0.7235, device='cuda:0')), ('log_bet_z', tensor(3.4042, device='cuda:0')), ('log_bet_xy', tensor(0.5877, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7235, device='cuda:0')), ('blur.log_bet_z', tensor(3.4042, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5877, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00192598 OrderedDict([('log_ez0', tensor(0.7539, device='cuda:0')), ('log_bet_z', tensor(3.4292, device='cuda:0')), ('log_bet_xy', tensor(0.6732, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7539, device='cuda:0')), ('blur.log_bet_z', tensor(3.4292, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6732, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00192545 OrderedDict([('log_ez0', tensor(0.7670, device='cuda:0')), ('log_bet_z', tensor(3.4391, device='cuda:0')), ('log_bet_xy', tensor(0.7524, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7670, device='cuda:0')), ('blur.log_bet_z', tensor(3.4391, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7524, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00192537 OrderedDict([('log_ez0', tensor(0.7685, device='cuda:0')), ('log_bet_z', tensor(3.4405, device='cuda:0')), ('log_bet_xy', tensor(0.8245, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.7685, device='cuda:0')), ('blur.log_bet_z', tensor(3.4405, device='cuda:0')), ('blur.log_bet_xy', tensor(0.8245, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# beads_002_roi001
# epoch 0, loss 0.00215016 OrderedDict([('log_ez0', tensor(0.2300, device='cuda:0')), ('log_bet_z', tensor(3.0057, device='cuda:0')), ('log_bet_xy', tensor(0.0100, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.2300, device='cuda:0')), ('blur.log_bet_z', tensor(3.0057, device='cuda:0')), ('blur.log_bet_xy', tensor(0.0100, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 10, loss 0.00183540 OrderedDict([('log_ez0', tensor(0.3295, device='cuda:0')), ('log_bet_z', tensor(3.1037, device='cuda:0')), ('log_bet_xy', tensor(0.1096, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.3295, device='cuda:0')), ('blur.log_bet_z', tensor(3.1037, device='cuda:0')), ('blur.log_bet_xy', tensor(0.1096, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 20, loss 0.00157678 OrderedDict([('log_ez0', tensor(0.4264, device='cuda:0')), ('log_bet_z', tensor(3.1910, device='cuda:0')), ('log_bet_xy', tensor(0.2082, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.4264, device='cuda:0')), ('blur.log_bet_z', tensor(3.1910, device='cuda:0')), ('blur.log_bet_xy', tensor(0.2082, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 30, loss 0.00139005 OrderedDict([('log_ez0', tensor(0.5160, device='cuda:0')), ('log_bet_z', tensor(3.2628, device='cuda:0')), ('log_bet_xy', tensor(0.3053, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5160, device='cuda:0')), ('blur.log_bet_z', tensor(3.2628, device='cuda:0')), ('blur.log_bet_xy', tensor(0.3053, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 40, loss 0.00128074 OrderedDict([('log_ez0', tensor(0.5919, device='cuda:0')), ('log_bet_z', tensor(3.3257, device='cuda:0')), ('log_bet_xy', tensor(0.4007, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.5919, device='cuda:0')), ('blur.log_bet_z', tensor(3.3257, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4007, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 50, loss 0.00123562 OrderedDict([('log_ez0', tensor(0.6479, device='cuda:0')), ('log_bet_z', tensor(3.3763, device='cuda:0')), ('log_bet_xy', tensor(0.4929, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6479, device='cuda:0')), ('blur.log_bet_z', tensor(3.3763, device='cuda:0')), ('blur.log_bet_xy', tensor(0.4929, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 60, loss 0.00122622 OrderedDict([('log_ez0', tensor(0.6813, device='cuda:0')), ('log_bet_z', tensor(3.4050, device='cuda:0')), ('log_bet_xy', tensor(0.5803, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6813, device='cuda:0')), ('blur.log_bet_z', tensor(3.4050, device='cuda:0')), ('blur.log_bet_xy', tensor(0.5803, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 70, loss 0.00122652 OrderedDict([('log_ez0', tensor(0.6941, device='cuda:0')), ('log_bet_z', tensor(3.4163, device='cuda:0')), ('log_bet_xy', tensor(0.6614, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6941, device='cuda:0')), ('blur.log_bet_z', tensor(3.4163, device='cuda:0')), ('blur.log_bet_xy', tensor(0.6614, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 80, loss 0.00122623 OrderedDict([('log_ez0', tensor(0.6936, device='cuda:0')), ('log_bet_z', tensor(3.4160, device='cuda:0')), ('log_bet_xy', tensor(0.7352, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6936, device='cuda:0')), ('blur.log_bet_z', tensor(3.4160, device='cuda:0')), ('blur.log_bet_xy', tensor(0.7352, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# epoch 90, loss 0.00122535 OrderedDict([('log_ez0', tensor(0.6881, device='cuda:0')), ('log_bet_z', tensor(3.4109, device='cuda:0')), ('log_bet_xy', tensor(0.8015, device='cuda:0')), ('log_k', tensor(0., device='cuda:0')), ('log_l', tensor(0., device='cuda:0')), ('emission.log_ez0', tensor(0.6881, device='cuda:0')), ('blur.log_bet_z', tensor(3.4109, device='cuda:0')), ('blur.log_bet_xy', tensor(0.8015, device='cuda:0')), ('blur.log_k', tensor(0., device='cuda:0')), ('blur.log_l', tensor(0., device='cuda:0'))])
# [0.002049863338470459,
#  0.007775517180562019,
#  0.006032835692167282,
#  0.001776835648342967,
#  0.002157449722290039,
#  0.0035237446427345276,
#  0.0013617335353046656,
#  0.0008467287989333272,
#  0.0027026510797441006,
#  0.0019248308381065726,
#  0.001224910607561469]
